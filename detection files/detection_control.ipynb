# %%
#!git clone https://github.com/WongKinYiu/yolov7

# %%
#!pip install -r requirements.txt

# %%
# !python "../yolov7/detect.py" --view-img --device "cpu" --weights "test files/best.pt" --conf 0.6 --img-size 416  --source "test files/test_video.mp4"
